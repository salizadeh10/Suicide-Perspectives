# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
import pymongo
import jsonify
from flask import Flask, render_template

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
#conn = 'mongodb://localhost:27017'
conn = 'mongodb://simon:Letmein12!@ds225624.mlab.com:25624/heroku_jt314qxs'
client = pymongo.MongoClient(conn)

# Declare the Mongo database
# db = client.suicide_DB
db = client.heroku_jt314qxs

# %%
# Declare the collection

results = db.male_and_female_suicide_rate.find()

suicide_rate = []

for result in results:
    print(result)
    #suicide_rate_dict = dict(suicide_rate_dict.items() + reslut.items())
    suicide_rate.append(result)
# Out:
# {'_id': ObjectId('5c07449057b9820fea9e3b9d'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': '2004', 'Male suicide rate (age-adjusted male suicides per 100,000)': '4.884803772', 'Female suicide rate (age-adjusted female suicides per 100,000)': '8.630155563'}
# {'_id': ObjectId('5c07449357b9820fea9e3b9e'), 'Entity': 'Albania', 'Code': 'ALB', 'Year': '2004', 'Male suicide rate (age-adjusted male suicides per 100,000)': '9.330574036', 'Female suicide rate (age-adjusted female suicides per 100,000)': '6.060874939'}
# {'_id': ObjectId('5c07449357b9820fea9e3b9f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': '2004', 'Male suicide rate (age-adjusted male suicides per 100,000)': '5.145025253', 'Female suicide rate (age-adjusted female suicides per 100,000)': '4.600764751'}
# ...

# %%
type(result)
# Out:
# dict

# %%
suicide_rate
# Out:
# [{'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Female suicide rate (age-adjusted female suicides per 100,000)': '8.630155563',
#   'Male suicide rate (age-adjusted male suicides per 100,000)': '4.884803772',
#   'Year': '2004',
#   '_id': ObjectId('5c06048c3a564a06dc9a7d2a')},
#  {'Code': 'ALB',
#   'Entity': 'Albania',
#   'Female suicide rate (age-adjusted female suicides per 100,000)': '6.060874939',
#   'Male suicide rate (age-adjusted male suicides per 100,000)': '9.330574036',
#   'Year': '2004',
#   '_id': ObjectId('5c06048c3a564a06dc9a7d2b')},
#  {'Code': 'DZA',
#   'Entity': 'Algeria',
#   'Female suicide rate (age-adjusted female suicides per 100,000)': '4.600764751',
#   'Male suicide rate (age-adjusted male suicides per 100,000)': '5.145025253',
#   'Year': '2004',
#   '_id': ObjectId('5c06048c3a564a06dc9a7d2c')},
#  {'Code': 'AND',
#   'Entity': 'Andorra',
#   'Female suicide rate (age-adjusted female suicides per 100,000)': '2.902797222',
# ...

# %%
# Declare the collection

results = db.suicide_rates_by_country.find()

country_rate = []

for result in results:
    print(result)
    country_rate.append(result)
# Out:
# {'_id': ObjectId('5c074dbc57b9820fea9eaf63'), 'Entity': 'Afghanistan', 'iso3': 'AFG', 'Year': '2002', 'suicide_rate': '6.867054'}
# {'_id': ObjectId('5c074dbc57b9820fea9eaf64'), 'Entity': 'Afghanistan', 'iso3': 'AFG', 'Year': '2004', 'suicide_rate': '6.6843853'}
# {'_id': ObjectId('5c074dbd57b9820fea9eaf65'), 'Entity': 'Afghanistan', 'iso3': 'AFG', 'Year': '2005', 'suicide_rate': '6.6843853'}
# {'_id': ObjectId('5c074dbd57b9820fea9eaf66'), 'Entity': 'Albania', 'iso3': 'ALB', 'Year': '2002', 'suicide_rate': '2.792918'}
# {'_id': ObjectId('5c074dbd57b9820fea9eaf67'), 'Entity': 'Albania', 'iso3': 'ALB', 'Year': '2004', 'suicide_rate': '7.699329853'}
# {'_id': ObjectId('5c074dbd57b9820fea9eaf68'), 'Entity': 'Albania', 'iso3': 'ALB', 'Year': '2005', 'suicide_rate': '7.699329853'}
# {'_id': ObjectId('5c074dbd57b9820fea9eaf69'), 'Entity': 'Algeria', 'iso3': 'DZA', 'Year': '2002', 'suicide_rate': '3.754641'}
# ...

# %%
country_rate
# Out:
# [{'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2002',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e4'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.867054'},
#  {'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2004',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e5'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'},
#  {'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2005',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e6'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'},
#  {'Code': 'ALB',
#   'Entity': 'Albania',
#   'Year': '2002',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e7'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '2.792918'},
#  {'Code': 'ALB',
#   'Entity': 'Albania',
#   'Year': '2004',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e8'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '7.699329853'},
#  {'Code': 'ALB',
# ...

# %%
# Declare the collection

results = db.suicide_rates_by_country.find()

country_rate = []
rate = {}

for result in results:
    print(result)
    country_rate.append(result)
# Out:
# {'_id': ObjectId('5c06049d3a564a06dc9ad8e4'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': '2002', 'suicide rate (age-adjusted suicides per 100,000 people)': '6.867054'}
# {'_id': ObjectId('5c06049d3a564a06dc9ad8e5'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': '2004', 'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'}
# {'_id': ObjectId('5c06049d3a564a06dc9ad8e6'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': '2005', 'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'}
# {'_id': ObjectId('5c06049d3a564a06dc9ad8e7'), 'Entity': 'Albania', 'Code': 'ALB', 'Year': '2002', 'suicide rate (age-adjusted suicides per 100,000 people)': '2.792918'}
# {'_id': ObjectId('5c06049d3a564a06dc9ad8e8'), 'Entity': 'Albania', 'Code': 'ALB', 'Year': '2004', 'suicide rate (age-adjusted suicides per 100,000 people)': '7.699329853'}
# ...

# %%
country_rate
# Out:
# [{'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2002',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e4'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.867054'},
#  {'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2004',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e5'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'},
#  {'Code': 'AFG',
#   'Entity': 'Afghanistan',
#   'Year': '2005',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e6'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '6.6843853'},
#  {'Code': 'ALB',
#   'Entity': 'Albania',
#   'Year': '2002',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e7'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '2.792918'},
#  {'Code': 'ALB',
#   'Entity': 'Albania',
#   'Year': '2004',
#   '_id': ObjectId('5c06049d3a564a06dc9ad8e8'),
#   'suicide rate (age-adjusted suicides per 100,000 people)': '7.699329853'},
#  {'Code': 'ALB',
# ...

# %%
d = {}

for item in country_rate:
    d[item] = 0

print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-47988fee297a> in <module>()
#       2
#       3 for item in country_rate:
# ----> 4     d[item] = 0
#       5
#       6 print(d)
#
# TypeError: unhashable type: 'dict'

# %%
type(rate)
# Out:
# list
